# %%
#import necessary packages
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import datetime
from dateutil.relativedelta import relativedelta
from datetime import date
from datetime import datetime

# %%
dateparse = lambda dates: [pd.datetime.strptime(d, '%Y-%m-%d %H:%M:%S') for d in dates]

# %%
#load in neccesary CSV files
diagnosis_icd9 = pd.read_csv("/project/projectdirs/m1532/Projects_MVP/_datasets/mimiciii/DIAGNOSES_ICD.csv", usecols= ["SUBJECT_ID", "ICD9_CODE"])
diag_name = pd.read_csv("/project/projectdirs/m1532/Projects_MVP/_datasets/mimiciii/D_ICD_DIAGNOSES.csv", usecols= ["ICD9_CODE", "LONG_TITLE"])
code_description = pd.read_csv("/project/projectdirs/m1532/Projects_MVP/_datasets/mimiciii/DRGCODES.csv")
patients = pd.read_csv("/project/projectdirs/m1532/Projects_MVP/_datasets/mimiciii/PATIENTS.csv", parse_dates= ["DOB"], date_parser=dateparse, usecols=["SUBJECT_ID", "DOB"])
admissions = pd.read_csv("/project/projectdirs/m1532/Projects_MVP/_datasets/mimiciii/ADMISSIONS.csv", parse_dates= ["ADMITTIME"], date_parser=dateparse, usecols=["SUBJECT_ID", "ADMITTIME"])
diagnosis_icd9.head()
# Out:
# /global/homes/d/dsmorrow/.conda/envs/intern/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.
#    SUBJECT_ID ICD9_CODE
# 0         109     40301
# 1         109       486
# 2         109     58281
# 3         109      5855
# 4         109      4254

# %%
#filter for only "diseases of despair" ICD9 codes
diag_dd_DF = diagnosis_icd9[diagnosis_icd9["ICD9_CODE"].str.startswith(("327", "338", "339", "346", "295", "296", "297", "298", "300", "301", "302", "307", "309", "310", "311", "313"), na = False)]
diag_dd_DF.head()
# Out:
#      SUBJECT_ID ICD9_CODE
# 22          109     32723
# 24          109     33829
# 248         135       311
# 305          67       311
# 311          67       311

# %%
#bring in the dob column from separate csv
diag_dd_DF = pd.merge(diag_dd_DF, patients, on='SUBJECT_ID')
diag_dd_DF.head()
# Out:
#    SUBJECT_ID ICD9_CODE        DOB
# 0         109     32723 2117-08-07
# 1         109     33829 2117-08-07
# 2         109     32723 2117-08-07
# 3         109     33829 2117-08-07
# 4         109     32723 2117-08-07

# %%
#bring in the admittime column from separate csv
diag_dd_DF = pd.merge(diag_dd_DF, admissions, on="SUBJECT_ID")
diag_dd_DF.head()
# Out:
#    SUBJECT_ID ICD9_CODE        DOB           ADMITTIME
# 0         109     32723 2117-08-07 2137-11-04 19:36:00
# 1         109     32723 2117-08-07 2138-04-16 17:44:00
# 2         109     32723 2117-08-07 2140-01-19 13:25:00
# 3         109     32723 2117-08-07 2140-02-02 02:13:00
# 4         109     32723 2117-08-07 2140-04-07 19:51:00

# %%
diag_dd_DF['DOB'].isnull().values.any()
# Out:
# False

# %%
diag_dd_DF['ADMITTIME'].isnull().values.any()
# Out:
# False

# %%
#change dob and admittime from object to datetime
diag_dd_DF["DOB"] = pd.to_datetime(diag_dd_DF["DOB"]) 
diag_dd_DF["ADMITTIME"] = pd.to_datetime(diag_dd_DF["ADMITTIME"])

# %%
#find the age of the patient using .subtract
diag_dd_DF["AGE"] = diag_dd_DF["ADMITTIME"].subtract(diag_dd_DF["DOB"]).dt.days/365
diag_dd_DF["AGE"] = diag_dd_DF["AGE"].round()

# %%
#how many icd9 codes are there for the DD?
diag_dd_DF.groupby(['ICD9_CODE']).count()
# Out:
#            SUBJECT_ID   DOB  ADMITTIME   AGE
# ICD9_CODE
# 29502               1     1          1     1
# 29512               5     5          5     5
# 29520               8     8          8     8
# 29522               1     1          1     1
# 29524               2     2          2     2
# ...               ...   ...        ...   ...
# 34670               2     2          2     2
# 34680              38    38         38    38
# 34690            1362  1362       1362  1362
# 34691               4     4          4     4
# 34693               1     1          1     1
#
# [150 rows x 4 columns]

# %%
#as you can see, looking at 150 different ICD9 codes can be confusing
DF = diag_dd_DF[['SUBJECT_ID', 'ICD9_CODE']]
DF = DF.groupby(['ICD9_CODE'], as_index=False).count()
plt.title("Number of patients with Diseases of Despair", size=30)
plt.xlabel("ICD9_Code", size=20)
plt.ylabel("Total patients", size=20)
plt.xticks(size=10)
plt.yticks(size=10)
plt.bar(DF['ICD9_CODE'], DF['SUBJECT_ID'])
plt.rcParams['figure.figsize'] = [16, 10]
plt.show()

# %%
#lets look at the top 10 codes
TopDF = DF.sort_values(by=['SUBJECT_ID'], ascending=False)
TopDF = TopDF.head(10)
plt.title("Number of patients with Top 10 Diseases of Despair", size=30)
plt.xlabel("ICD9_Code", size=20)
plt.ylabel("Total patients", size=20)
plt.xticks(size=10)
plt.yticks(size=10)
plt.bar(TopDF['ICD9_CODE'], TopDF['SUBJECT_ID'], color = plt.cm.Paired(np.arange(len(TopDF))))
plt.rcParams['figure.figsize'] = [16, 10]
plt.show()

# %%
#merge in separate dataframe to include the name/description of the ICD9 code 
diagDFdesc = pd.merge(diag_dd_DF, diag_name, on='ICD9_CODE')
diagDFdesc
# Out:
#        SUBJECT_ID ICD9_CODE        DOB           ADMITTIME   AGE  \
# 0             109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 1             109     32723 2117-08-07 2138-04-16 17:44:00  21.0
# 2             109     32723 2117-08-07 2140-01-19 13:25:00  22.0
# 3             109     32723 2117-08-07 2140-02-02 02:13:00  23.0
# 4             109     32723 2117-08-07 2140-04-07 19:51:00  23.0
# ...           ...       ...        ...                 ...   ...
# 36375       99085     34691 2091-02-01 2131-02-08 16:25:00  40.0
# 36376       95841     33902 2111-12-01 2160-04-09 21:23:00  48.0
# 36377       96928     29621 2073-05-24 2138-06-03 12:36:00  65.0
# 36378       96928     29621 2073-05-24 2139-01-01 15:02:00  66.0
# 36379       99873      2982 2058-05-08 2103-12-19 14:58:00  46.0
#
#                                               LONG_TITLE
# 0             Obstructive sleep apnea (adult)(pediatric)
# 1             Obstructive sleep apnea (adult)(pediatric)
# 2             Obstructive sleep apnea (adult)(pediatric)
# 3             Obstructive sleep apnea (adult)(pediatric)
# 4             Obstructive sleep apnea (adult)(pediatric)
# ...                                                  ...
# 36375  Migraine, unspecified, with intractable migrai...
# 36376                           Chronic cluster headache
# 36377  Major depressive affective disorder, single ep...
# 36378  Major depressive affective disorder, single ep...
# 36379                                 Reactive confusion
#
# [36380 rows x 6 columns]

# %%
#Title of top 10 Icd9 diseases of despair
DF2 = diagDFdesc[['SUBJECT_ID', 'LONG_TITLE']]
DF2['Counts'] = np.zeros(len(DF2))
DF2_COUNT = DF2.groupby(['LONG_TITLE'], as_index=False).count()
DF2_C = DF2_COUNT.sort_values(by=['Counts'],ascending=False)
(DF2_C[['LONG_TITLE', 'Counts']].head(10))
# Out:
# /global/homes/d/dsmorrow/.conda/envs/intern/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                             LONG_TITLE  Counts
# 43       Depressive disorder, not elsewhere classified    9010
# 81          Obstructive sleep apnea (adult)(pediatric)    6858
# 50                                  Dysthymic disorder    3418
# 11                          Anxiety state, unspecified    3326
# 89                                  Other chronic pain    2723
# 76   Migraine, unspecified, without mention of intr...    1362
# 22                       Bipolar disorder, unspecified    1283
# 147             Unspecified schizophrenia, unspecified     777
# 114                      Posttraumatic stress disorder     739
# 125              Schizoaffective disorder, unspecified     517

# %%
#looking to see what the range of ages is
diag_dd_DF.sort_values(by=['AGE'],ascending=True)
# Out:
#        SUBJECT_ID ICD9_CODE        DOB           ADMITTIME    AGE
# 5257         7235       311 1850-01-20 2150-02-04 02:12:00 -285.0
# 29722       69262      3004 1811-07-24 2111-07-24 21:58:00 -285.0
# 29720       70682       311 1869-02-10 2169-02-10 12:03:00 -285.0
# 34465       91525       311 1860-05-28 2160-05-28 22:39:00 -285.0
# 29665       69702     34690 1890-02-10 2190-02-10 17:40:00 -285.0
# ...           ...       ...        ...                 ...    ...
# 1111           63      3079 2080-07-07 2169-01-07 01:50:00   89.0
# 12860       19155       311 2084-08-07 2173-08-02 17:12:00   89.0
# 25202       48253       311 2080-10-20 2169-09-08 22:44:00   89.0
# 29384       71915       311 2012-07-16 2101-03-08 04:57:00   89.0
# 6521        10222      3004 2093-02-22 2181-10-10 21:13:00   89.0
#
# [36382 rows x 5 columns]

# %%
#select only 18 and older
diag_dd_DF = diag_dd_DF[diag_dd_DF.AGE >= 18]
diag_dd_DF.sort_values(by=['AGE'],ascending=True)
# Out:
#        SUBJECT_ID ICD9_CODE        DOB           ADMITTIME   AGE
# 21753       31602     30981 2107-01-20 2125-04-11 23:59:00  18.0
# 23980       47591      3101 2150-08-04 2169-01-26 07:06:00  18.0
# 23981       47591      3380 2150-08-04 2169-01-26 07:06:00  18.0
# 23164       31037     29680 2171-11-23 2190-05-06 20:51:00  18.0
# 29561       69168     30000 2146-07-15 2164-11-11 10:50:00  18.0
# ...           ...       ...        ...                 ...   ...
# 4024         6283       311 2103-01-19 2191-07-07 05:49:00  89.0
# 35922       99559       311 2064-06-22 2153-06-11 21:08:00  89.0
# 4026         6283     30000 2103-01-19 2191-07-07 05:49:00  89.0
# 32929       78337     29570 2024-09-14 2113-07-14 03:23:00  89.0
# 32097       80156      3079 2085-03-02 2174-02-08 12:14:00  89.0
#
# [35603 rows x 5 columns]

# %%
diag_dd_DF = diag_dd_DF[['SUBJECT_ID', 'ICD9_CODE', 'AGE']]

# %%
notes = pd.read_csv("/project/projectdirs/m1532/Projects_MVP/_datasets/mimiciii/NOTEEVENTS.csv", usecols = ['SUBJECT_ID','CATEGORY', 'TEXT'])
notes.head()
# Out:
#    SUBJECT_ID           CATEGORY  \
# 0       22532  Discharge summary
# 1       13702  Discharge summary
# 2       13702  Discharge summary
# 3       13702  Discharge summary
# 4       26880  Discharge summary
#
#                                                 TEXT
# 0  Admission Date:  [**2151-7-16**]       Dischar...
# 1  Admission Date:  [**2118-6-2**]       Discharg...
# 2  Admission Date:  [**2119-5-4**]              D...
# 3  Admission Date:  [**2124-7-21**]              ...
# 4  Admission Date:  [**2162-3-3**]              D...

# %%
#merge dd dataframe with notes
icd9_dd_notes = pd.merge(diag_dd_DF, notes, on ='SUBJECT_ID')
icd9_dd_notes
# Out:
#          SUBJECT_ID ICD9_CODE   AGE           CATEGORY  \
# 0               109     32723  20.0  Discharge summary
# 1               109     32723  20.0  Discharge summary
# 2               109     32723  20.0  Discharge summary
# 3               109     32723  20.0  Discharge summary
# 4               109     32723  20.0  Discharge summary
# ...             ...       ...   ...                ...
# 8513837       97492       311  32.0            Nursing
# 8513838       97492       311  32.0         Physician
# 8513839       97492       311  32.0          Radiology
# 8513840       97492       311  32.0          Radiology
# 8513841       97492       311  32.0          Radiology
#
#                                                       TEXT
# 0        Admission Date:  [**2142-5-15**]              ...
# 1        Admission Date:  [**2142-5-20**]              ...
# 2        Admission Date:  [**2142-6-18**]              ...
# 3        Admission Date:  [**2142-7-3**]              D...
# 4        Admission Date:  [**2142-7-7**]              D...
# ...                                                    ...
# 8513837  TITLE:\n   Pt is 31 y/o woman with history of ...
# 8513838  SICU\n   HPI:\n   31 yo RH woman with a PMH de...
# 8513839  [**2158-8-1**] 10:43 AM\n MR HEAD W/O CONTRAST...
# 8513840  [**2158-7-31**] 8:52 PM\n CTA HEAD W&W/O C & R...
# 8513841  [**2158-7-31**] 8:54 PM\n CT HEAD W/O CONTRAST...
#
# [8513842 rows x 5 columns]

# %%
#how many entries?
icd9_dd_notes.count()
# Out:
# SUBJECT_ID    8513842
# ICD9_CODE     8513842
# AGE           8513842
# CATEGORY      8513842
# TEXT          8513842
# dtype: int64

# %%
#drop any duplicate TEXT entries 
icd9_notes_unique = icd9_dd_notes.drop_duplicates(subset='TEXT', keep='first')
icd9_notes_unique
# Out:
#          SUBJECT_ID ICD9_CODE   AGE           CATEGORY  \
# 0               109     32723  20.0  Discharge summary
# 1               109     32723  20.0  Discharge summary
# 2               109     32723  20.0  Discharge summary
# 3               109     32723  20.0  Discharge summary
# 4               109     32723  20.0  Discharge summary
# ...             ...       ...   ...                ...
# 8513819       97492     34680  32.0            Nursing
# 8513820       97492     34680  32.0         Physician
# 8513821       97492     34680  32.0          Radiology
# 8513822       97492     34680  32.0          Radiology
# 8513823       97492     34680  32.0          Radiology
#
#                                                       TEXT
# 0        Admission Date:  [**2142-5-15**]              ...
# 1        Admission Date:  [**2142-5-20**]              ...
# 2        Admission Date:  [**2142-6-18**]              ...
# 3        Admission Date:  [**2142-7-3**]              D...
# 4        Admission Date:  [**2142-7-7**]              D...
# ...                                                    ...
# 8513819  TITLE:\n   Pt is 31 y/o woman with history of ...
# 8513820  SICU\n   HPI:\n   31 yo RH woman with a PMH de...
# 8513821  [**2158-8-1**] 10:43 AM\n MR HEAD W/O CONTRAST...
# 8513822  [**2158-7-31**] 8:52 PM\n CTA HEAD W&W/O C & R...
# 8513823  [**2158-7-31**] 8:54 PM\n CT HEAD W/O CONTRAST...
#
# [432689 rows x 5 columns]

# %%
#after removing duplicates, how many entries do we have?
icd9_notes_unique.count()
# Out:
# SUBJECT_ID    432689
# ICD9_CODE     432689
# AGE           432689
# CATEGORY      432689
# TEXT          432689
# dtype: int64

# %%
icd9_dd_notes = icd9_notes_unique

# %%
#how many notes per category
icd9_dd_notes.groupby(["CATEGORY"]).count().sort_values(by=['TEXT'],ascending=False)
# Out:
#                    SUBJECT_ID  ICD9_CODE     DOB  ADMITTIME     AGE    TEXT
# CATEGORY
# Radiology              135365     135365  135365     135365  135365  135365
# Nursing                 73885      73885   73885      73885   73885   73885
# Nursing/other           68651      68651   68651      68651   68651   68651
# ECG                     55682      55682   55682      55682   55682   55682
# Physician               52143      52143   52143      52143   52143   52143
# Discharge summary       14191      14191   14191      14191   14191   14191
# Respiratory             11578      11578   11578      11578   11578   11578
# Echo                    11402      11402   11402      11402   11402   11402
# Nutrition                3347       3347    3347       3347    3347    3347
# General                  3007       3007    3007       3007    3007    3007
# Rehab Services           1893       1893    1893       1893    1893    1893
# Social Work              1037       1037    1037       1037    1037    1037
# Case Management           432        432     432        432     432     432
# Pharmacy                   43         43      43         43      43      43
# Consult                    33         33      33         33      33      33

# %%
#what is the largest number of entries for a patient?
#what is the least 
icd9_dd_notes.groupby(["SUBJECT_ID"]).count().sort_values(by=['TEXT'],ascending=False)
# Out:
#             ICD9_CODE   DOB  ADMITTIME   AGE  CATEGORY  TEXT
# SUBJECT_ID
# 78076            1317  1317       1317  1317      1317  1317
# 99383            1228  1228       1228  1228      1228  1228
# 109              1217  1217       1217  1217      1217  1217
# 27427            1209  1209       1209  1209      1209  1209
# 67906            1017  1017       1017  1017      1017  1017
# ...               ...   ...        ...   ...       ...   ...
# 67019               1     1          1     1         1     1
# 44611               1     1          1     1         1     1
# 90801               1     1          1     1         1     1
# 80688               1     1          1     1         1     1
# 85940               1     1          1     1         1     1
#
# [8210 rows x 6 columns]

# %%
#average number of notes per patient
#dont know how skewed this is (need to look at outliers)
icd9_dd_notes.groupby('SUBJECT_ID').count().mean()
# Out:
# ICD9_CODE    52.70268
# DOB          52.70268
# ADMITTIME    52.70268
# AGE          52.70268
# CATEGORY     52.70268
# TEXT         52.70268
# dtype: float64

# %%
#summary of the notes
#what is the std?
icd9_dd_notes["TEXT"].str.len().describe()
# Out:
# count    432689.000000
# mean       2437.127369
# std        3048.404448
# min           3.000000
# 25%         765.000000
# 50%        1362.000000
# 75%        2722.000000
# max       50663.000000
# Name: TEXT, dtype: float64

# %%
# Load the regular expression library
import re

# %%
# Remove punctuation and anything that isnt a character or number 
#this process took approximately (start 1:31:16 - finish 1:33:10) 2 minutes
icd9_dd_notes['text_processed'] = icd9_dd_notes['TEXT'].map(lambda x: re.sub('[\W]+', ' ', x))

# %%
# Convert to lowercase
icd9_dd_notes['text_processed'] = icd9_dd_notes['text_processed'].map(lambda x: x.lower())

# %%
# Print out the first rows of papers to ensure re working properly
icd9_dd_notes['text_processed'].head()
# Out:
# 0    admission date 2142 5 15 discharge date 2142 5...
# 1    admission date 2142 5 20 discharge date 2142 6...
# 2    admission date 2142 6 18 discharge date 2142 6...
# 3    admission date 2142 7 3 discharge date 2142 7 ...
# 4    admission date 2142 7 7 discharge date 2142 7 ...
# Name: text_processed, dtype: object

# %%
icd9_dd_notes.head()
# Out:
#    SUBJECT_ID ICD9_CODE        DOB           ADMITTIME   AGE  \
# 0         109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 1         109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 2         109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 3         109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 4         109     32723 2117-08-07 2137-11-04 19:36:00  20.0
#
#             CATEGORY                                               TEXT  \
# 0  Discharge summary  Admission Date:  [**2142-5-15**]              ...
# 1  Discharge summary  Admission Date:  [**2142-5-20**]              ...
# 2  Discharge summary  Admission Date:  [**2142-6-18**]              ...
# 3  Discharge summary  Admission Date:  [**2142-7-3**]              D...
# 4  Discharge summary  Admission Date:  [**2142-7-7**]              D...
#
#                                       text_processed
# 0  admission date 2142 5 15 discharge date 2142 5...
# 1  admission date 2142 5 20 discharge date 2142 6...
# 2  admission date 2142 6 18 discharge date 2142 6...
# 3  admission date 2142 7 3 discharge date 2142 7 ...
# 4  admission date 2142 7 7 discharge date 2142 7 ...

# %%
#adding additional index column for calling
index = tuple(range(0, 432689, 1))
icd9_dd_notes["index"] = index
icd9_dd_notes
# Out:
#          SUBJECT_ID ICD9_CODE        DOB           ADMITTIME   AGE  \
# 0               109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 1               109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 2               109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 3               109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# 4               109     32723 2117-08-07 2137-11-04 19:36:00  20.0
# ...             ...       ...        ...                 ...   ...
# 8513819       97492     34680 2126-09-04 2158-07-31 22:29:00  32.0
# 8513820       97492     34680 2126-09-04 2158-07-31 22:29:00  32.0
# 8513821       97492     34680 2126-09-04 2158-07-31 22:29:00  32.0
# 8513822       97492     34680 2126-09-04 2158-07-31 22:29:00  32.0
# 8513823       97492     34680 2126-09-04 2158-07-31 22:29:00  32.0
#
#                   CATEGORY                                               TEXT  \
# 0        Discharge summary  Admission Date:  [**2142-5-15**]              ...
# 1        Discharge summary  Admission Date:  [**2142-5-20**]              ...
# 2        Discharge summary  Admission Date:  [**2142-6-18**]              ...
# 3        Discharge summary  Admission Date:  [**2142-7-3**]              D...
# 4        Discharge summary  Admission Date:  [**2142-7-7**]              D...
# ...                    ...                                                ...
# 8513819            Nursing  TITLE:\n   Pt is 31 y/o woman with history of ...
# 8513820         Physician   SICU\n   HPI:\n   31 yo RH woman with a PMH de...
# 8513821          Radiology  [**2158-8-1**] 10:43 AM\n MR HEAD W/O CONTRAST...
# 8513822          Radiology  [**2158-7-31**] 8:52 PM\n CTA HEAD W&W/O C & R...
# 8513823          Radiology  [**2158-7-31**] 8:54 PM\n CT HEAD W/O CONTRAST...
#
#                                             text_processed   index
# 0        admission date 2142 5 15 discharge date 2142 5...       0
# 1        admission date 2142 5 20 discharge date 2142 6...       1
# 2        admission date 2142 6 18 discharge date 2142 6...       2
# 3        admission date 2142 7 3 discharge date 2142 7 ...       3
# 4        admission date 2142 7 7 discharge date 2142 7 ...       4
# ...                                                    ...     ...
# 8513819  title pt is 31 y o woman with history of heada...  432684
# 8513820  sicu hpi 31 yo rh woman with a pmh depression ...  432685
# 8513821   2158 8 1 10 43 am mr head w o contrast clip c...  432686
# 8513822   2158 7 31 8 52 pm cta head w w o c recons cta...  432687
# 8513823   2158 7 31 8 54 pm ct head w o contrast outsid...  432688
#
# [432689 rows x 9 columns]

# %%
#icd9_dd_notes.to_csv('Full_Table_ICD9_Notes.csv')

# %%
data_text = icd9_dd_notes[['text_processed','index']]
data_text
# Out:
#                                             text_processed   index
# 0        admission date 2142 5 15 discharge date 2142 5...       0
# 1        admission date 2142 5 20 discharge date 2142 6...       1
# 2        admission date 2142 6 18 discharge date 2142 6...       2
# 3        admission date 2142 7 3 discharge date 2142 7 ...       3
# 4        admission date 2142 7 7 discharge date 2142 7 ...       4
# ...                                                    ...     ...
# 8513819  title pt is 31 y o woman with history of heada...  432684
# 8513820  sicu hpi 31 yo rh woman with a pmh depression ...  432685
# 8513821   2158 8 1 10 43 am mr head w o contrast clip c...  432686
# 8513822   2158 7 31 8 52 pm cta head w w o c recons cta...  432687
# 8513823   2158 7 31 8 54 pm ct head w o contrast outsid...  432688
#
# [432689 rows x 2 columns]

# %%
documents = data_text

# %%
#import necessary packages for further word processing
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2020)
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /global/homes/d/dsmorrow/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#function to perform lemmatize and stem preprocessing steps on the data set.
def lemmatize_stemming(text):
    stemmer = PorterStemmer()
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
#test the stemmer and lem on one example text
doc_sample = documents[documents['index'] == 4310].values[0][0]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# original document:
# ['', 'last', 'name', 'lf', 'first', 'name3', 'lf', '1567', 'm', 'nsurg', 'fa11', '2127', '5', '8', '11', '00', 'am', 'unilat', 'lower', 'ext', 'veins', 'left', 'clip', 'clip', 'number', 'radiology', '20658', 'reason', 'lleg', 'tenderness', 'assess', 'for', 'dvt', 'admitting', 'diagnosis', 'post', 'op', 'infection', '______________________________________________________________________________', 'hospital', '3', 'medical', 'condition', '59', 'year', 'old', 'woman', 'with', 'lle', 'tenderness', 'reason', 'for', 'this', 'examination', 'please', 'r', 'o', 'dvt', '______________________________________________________________________________', 'pfi', 'report', 'no', 'left', 'lower', 'extremity', 'dvt', '']
#
#
#  tokenized and lemmatized document:
# ['nsurg', 'unilat', 'lower', 'vein', 'leav', 'clip', 'clip', 'number', 'radiolog', 'reason', 'lleg', 'tender', 'assess', 'admit', 'diagnosi', 'post', 'infect', 'hospit', 'medic', 'condit', 'year', 'woman', 'tender', 'reason', 'examin', 'report', 'leav', 'lower', 'extrem']

# %%
#remove any na that would cause problems in the lda model
documents = documents.dropna(subset=['text_processed'])

# %%
#only looking at first 1000 documents for quicker processing
doc_group1 = documents.iloc[0:10000]
doc_group1
# Out:
#                                             text_processed  index
# 0        admission date 2142 5 15 discharge date 2142 5...      0
# 1        admission date 2142 5 20 discharge date 2142 6...      1
# 2        admission date 2142 6 18 discharge date 2142 6...      2
# 3        admission date 2142 7 3 discharge date 2142 7 ...      3
# 4        admission date 2142 7 7 discharge date 2142 7 ...      4
# ...                                                    ...    ...
# 1500324   2183 6 22 10 03 pm ct head w o contrast clip ...   9995
# 1500325   2183 6 19 12 11 am ct head w o contrast clip ...   9996
# 1500326   2183 6 19 11 50 am humerus ap lat right upper...   9997
# 1500327   2183 6 18 4 53 pm shoulder ap neutral axillar...   9998
# 1500328   2183 6 27 3 59 pm abdomen supine only clip cl...   9999
#
# [10000 rows x 2 columns]

# %%
#doc_group1.to_csv('Text_Processed.csv')

# %%
#use preprocess function on group1
processed_docs = doc_group1['text_processed'].map(preprocess)
processed_docs
# Out:
# 0          [admiss, date, discharg, date, date, birth, se...
# 1          [admiss, date, discharg, date, date, birth, se...
# 2          [admiss, date, discharg, date, date, birth, se...
# 3          [admiss, date, discharg, date, date, birth, se...
# 4          [admiss, date, discharg, date, date, birth, se...
#                                  ...
# 1500324    [head, contrast, clip, clip, number, radiolog,...
# 1500325    [head, contrast, clip, clip, number, radiolog,...
# 1500326    [humeru, right, upper, extrem, fluoro, radiolo...
# 1500327    [shoulder, neutral, axillari, trauma, right, c...
# 1500328    [abdomen, supin, clip, clip, number, radiolog,...
# Name: text_processed, Length: 10000, dtype: object

# %%
#checking to make sure all words are being separated and stemmed properly
#processed_docs.iloc[3]

# %%
#create dictionary of words and number of appearances 
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 abdomen
# 1 abdomin
# 2 abl
# 3 abnorm
# 4 abus
# 5 accid
# 6 acut
# 7 admiss
# 8 admit
# 9 afebril
# 10 agre

# %%
#filter out words that appear in less than (15) documents
#only keep the first 10000
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
#go through each document and report words and occurrences using doc2box for token id and amount
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
#identify what the word is based on token and number of appearances
#765 is a sample index from documents
bow_doc_765 = bow_corpus[765]
for i in range(len(bow_doc_765)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_765[i][0], 
dictionary[bow_doc_765[i][0]], 
bow_doc_765[i][1]))
# Out:
# Word 6 ("acut") appears 1 time.
# Word 7 ("admiss") appears 2 time.
# Word 10 ("agre") appears 1 time.
# Word 13 ("allergi") appears 1 time.
# Word 35 ("blood") appears 1 time.
# Word 37 ("bridg") appears 1 time.
# Word 46 ("chang") appears 1 time.
# Word 47 ("check") appears 1 time.
# Word 48 ("chief") appears 1 time.
# Word 51 ("chronic") appears 1 time.
# Word 58 ("complaint") appears 1 time.
# Word 64 ("control") appears 2 time.
# Word 65 ("coumadin") appears 1 time.
# Word 70 ("crisi") appears 1 time.
# Word 93 ("disposit") appears 1 time.
# Word 97 ("drip") appears 1 time.
# Word 102 ("emerg") appears 1 time.
# Word 108 ("esrd") appears 1 time.
# Word 112 ("event") appears 1 time.
# Word 117 ("famili") appears 1 time.
# Word 131 ("glucos") appears 1 time.
# Word 145 ("histori") appears 1 time.
# Word 149 ("hour") appears 2 time.
# Word 154 ("hypertens") appears 3 time.
# Word 157 ("imag") appears 1 time.
# Word 160 ("includ") appears 1 time.
# Word 174 ("labetalol") appears 1 time.
# Word 179 ("line") appears 2 time.
# Word 187 ("malign") appears 1 time.
# Word 189 ("med") appears 1 time.
# Word 190 ("medic") appears 3 time.
# Word 199 ("morphin") appears 1 time.
# Word 205 ("nausea") appears 2 time.
# Word 211 ("nifedipin") appears 1 time.
# Word 215 ("note") appears 3 time.
# Word 223 ("pain") appears 3 time.
# Word 225 ("patch") appears 2 time.
# Word 226 ("patient") appears 1 time.
# Word 228 ("penicillin") appears 1 time.
# Word 229 ("percocet") appears 1 time.
# Word 235 ("physic") appears 2 time.
# Word 240 ("prednison") appears 1 time.
# Word 242 ("present") appears 1 time.
# Word 250 ("provid") appears 1 time.
# Word 256 ("rebound") appears 1 time.
# Word 267 ("restart") appears 1 time.
# Word 270 ("review") appears 2 time.
# Word 281 ("servic") appears 1 time.
# Word 286 ("sign") appears 1 time.
# Word 290 ("sodium") appears 1 time.
# Word 298 ("stool") appears 1 time.
# Word 308 ("system") appears 2 time.
# Word 319 ("time") appears 1 time.
# Word 323 ("total") appears 3 time.
# Word 336 ("urgenc") appears 2 time.
# Word 341 ("vital") appears 1 time.
# Word 342 ("vomit") appears 1 time.
# Word 362 ("antibiot") appears 1 time.
# Word 377 ("better") appears 1 time.
# Word 393 ("code") appears 1 time.
# Word 408 ("diet") appears 1 time.
# Word 413 ("dose") appears 1 time.
# Word 424 ("feel") appears 1 time.
# Word 428 ("floor") appears 1 time.
# Word 440 ("hemodynam") appears 1 time.
# Word 442 ("heparin") appears 3 time.
# Word 444 ("hold") appears 1 time.
# Word 459 ("keppra") appears 2 time.
# Word 460 ("lab") appears 2 time.
# Word 465 ("level") appears 1 time.
# Word 471 ("lipas") appears 1 time.
# Word 495 ("nutrit") appears 1 time.
# Word 523 ("radiolog") appears 1 time.
# Word 570 ("transfer") appears 1 time.
# Word 576 ("ulcer") appears 1 time.
# Word 577 ("unchang") appears 2 time.
# Word 580 ("urin") appears 1 time.
# Word 599 ("celexa") appears 1 time.
# Word 611 ("examin") appears 2 time.
# Word 615 ("fluid") appears 1 time.
# Word 638 ("rash") appears 1 time.
# Word 648 ("aliskerin") appears 1 time.
# Word 651 ("care") appears 1 time.
# Word 681 ("oral") appears 1 time.
# Word 683 ("overnight") appears 2 time.
# Word 687 ("plan") appears 2 time.
# Word 715 ("evid") appears 1 time.
# Word 722 ("mmhg") appears 1 time.
# Word 725 ("product") appears 1 time.
# Word 730 ("troponin") appears 1 time.
# Word 757 ("gaug") appears 2 time.
# Word 811 ("acetaminophen") appears 1 time.
# Word 817 ("commun") appears 1 time.
# Word 829 ("heart") appears 1 time.
# Word 836 ("monitor") appears 1 time.
# Word 840 ("organ") appears 1 time.
# Word 846 ("prophylaxi") appears 2 time.
# Word 929 ("respiratori") appears 1 time.
# Word 932 ("rhythm") appears 2 time.
# Word 936 ("sinu") appears 1 time.
# Word 939 ("support") appears 1 time.
# Word 1025 ("itch") appears 2 time.
# Word 1073 ("spend") appears 1 time.
# Word 1077 ("statu") appears 1 time.
# Word 1146 ("fact") appears 1 time.
# Word 1197 ("run") appears 1 time.
# Word 1205 ("slowli") appears 1 time.
# Word 1209 ("stress") appears 1 time.
# Word 1229 ("amylas") appears 1 time.
# Word 1239 ("assess") appears 2 time.
# Word 1334 ("oxycodon") appears 1 time.
# Word 1376 ("tunnel") appears 1 time.
# Word 1446 ("drain") appears 1 time.
# Word 1516 ("data") appears 1 time.
# Word 1613 ("fell") appears 1 time.
# Word 1614 ("infus") appears 1 time.
# Word 1636 ("insp") appears 1 time.
# Word 1672 ("eat") appears 1 time.
# Word 1924 ("resid") appears 1 time.
# Word 1987 ("tmax") appears 1 time.
# Word 2034 ("injuri") appears 1 time.
# Word 2046 ("tcurrent") appears 1 time.
# Word 2088 ("balanc") appears 2 time.
# Word 2090 ("ckmb") appears 1 time.
# Word 2092 ("deliveri") appears 1 time.
# Word 2093 ("devic") appears 1 time.
# Word 2095 ("flowsheet") appears 1 time.
# Word 2096 ("glycem") appears 1 time.
# Word 2098 ("tropt") appears 1 time.
# Word 2121 ("paramet") appears 1 time.
# Word 2165 ("portion") appears 1 time.
# Word 2375 ("fent") appears 1 time.
# Word 2473 ("hickman") appears 1 time.
# Word 2545 ("shut") appears 1 time.

# %%
#determine the TF-IDF scores or weight of a word within documents
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.01174127447468137),
#  (1, 0.042560102085011514),
#  (2, 0.013240844268555),
#  (3, 0.011531258310402108),
#  (4, 0.022558887584786597),
#  (5, 0.02614025107563493),
#  (6, 0.009256616374237926),
#  (7, 0.05135875711887838),
#  (8, 0.031606779032053646),
#  (9, 0.013732995337538419),
#  (10, 0.017973752374343836),
#  (11, 0.013633602464447492),
#  (12, 0.06323567825336546),
#  (13, 0.011354939226261324),
#  (14, 0.015941520634870664),
#  (15, 0.022938091455436443),
#  (16, 0.024309197216208066),
#  (17, 0.047323658264600964),
#  (18, 0.024495529504448683),
#  (19, 0.036034632434941274),
#  (20, 0.03836432151668879),
#  (21, 0.042519259187031484),
#  (22, 0.01680545600090811),
#  (23, 0.030944900370877236),
#  (24, 0.022330522793082237),
#  (25, 0.024263584704635948),
#  (26, 0.03713787476543285),
#  (27, 0.026239818444966784),
#  (28, 0.024837630419162596),
#  (29, 0.02115543166528828),
#  (30, 0.026819667507489903),
#  (31, 0.01065528236963484),
#  (32, 0.018473069671452423),
#  (33, 0.02890544724560623),
#  (34, 0.028547176081460422),
#  (35, 0.056440290984754476),
#  (36, 0.019671878930230317),
#  (37, 0.02412897529669059),
#  (38, 0.018970059478636548),
#  (39, 0.018301540752184667),
#  (40, 0.018210187799879877),
#  (41, 0.017502750526806922),
#  (42, 0.011084090225556408),
#  (324, 0.1613548015843204),
#  (325, 0.018105493661107197),
#  (326, 0.015143020075945349),
#  (327, 0.016689740651102687),
#  (328, 0.02767898867756554),
#  (329, 0.031928653781313446),
#  (330, 0.021697375353848625),
#  (331, 0.014377856567993025),
#  (332, 0.019182160758344394),
#  (333, 0.04081723865277018),
#  (334, 0.013192150474090268),
#  (335, 0.025148823493081653),
#  (336, 0.10477839630258885),
#  (337, 0.023702693826868217),
#  (338, 0.022728017116885515),
#  (339, 0.024543116607779192),
#  (340, 0.02242723395862819),
#  (341, 0.011949958857917123),
#  (342, 0.03037280107742758),
#  (343, 0.013234733899831862),
#  (344, 0.0395024978348467),
#  (345, 0.01548163360628915),
#  (346, 0.012811734768775522),
#  (347, 0.10356150926212247),
#  (348, 0.23383979848518416),
#  (349, 0.015509276293728017),
#  (350, 0.03150971049816273),
#  (351, 0.023661829132300482),
#  (352, 0.01480777739352281),
#  (353, 0.005392374250959907),
#  (354, 0.015177697011795502)]

# %%
#train lda model using only bow_corpus
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.019*"reason" + 0.018*"clip" + 0.016*"chest" + 0.015*"right" + 0.014*"leav" + 0.011*"hospit" + 0.011*"medic" + 0.011*"year" + 0.010*"examin" + 0.009*"radiolog"
# Topic: 1
# Words: 0.016*"patient" + 0.010*"right" + 0.010*"leav" + 0.007*"clip" + 0.007*"imag" + 0.007*"contrast" + 0.006*"reason" + 0.006*"normal" + 0.006*"procedur" + 0.006*"line"
# Topic: 2
# Words: 0.009*"pain" + 0.007*"continu" + 0.007*"patient" + 0.007*"leav" + 0.007*"medic" + 0.007*"chest" + 0.007*"assess" + 0.006*"chronic" + 0.006*"note" + 0.006*"right"
# Topic: 3
# Words: 0.018*"trace" + 0.017*"leav" + 0.016*"chang" + 0.014*"contrast" + 0.014*"previou" + 0.013*"sinu" + 0.011*"rhythm" + 0.010*"wave" + 0.009*"normal" + 0.008*"compar"
# Topic: 4
# Words: 0.012*"patient" + 0.012*"pain" + 0.009*"medic" + 0.009*"assess" + 0.009*"blood" + 0.008*"continu" + 0.008*"hypertens" + 0.007*"histori" + 0.007*"leav" + 0.006*"tablet"
# Topic: 5
# Words: 0.016*"tablet" + 0.014*"leav" + 0.014*"right" + 0.010*"hospit" + 0.009*"patient" + 0.009*"daili" + 0.008*"discharg" + 0.008*"clip" + 0.008*"arteri" + 0.007*"reason"
# Topic: 6
# Words: 0.015*"right" + 0.013*"pain" + 0.011*"clip" + 0.010*"medic" + 0.009*"chest" + 0.009*"reason" + 0.009*"leav" + 0.008*"patient" + 0.008*"year" + 0.008*"hospit"
# Topic: 7
# Words: 0.011*"note" + 0.011*"pain" + 0.009*"plan" + 0.007*"continu" + 0.007*"give" + 0.007*"chang" + 0.006*"patient" + 0.006*"resp" + 0.006*"follow" + 0.006*"clear"
# Topic: 8
# Words: 0.040*"normal" + 0.036*"valv" + 0.026*"leav" + 0.022*"aortic" + 0.020*"mitral" + 0.018*"leaflet" + 0.017*"ventricular" + 0.017*"right" + 0.014*"size" + 0.013*"systol"
# Topic: 9
# Words: 0.018*"right" + 0.014*"contrast" + 0.013*"clip" + 0.012*"reason" + 0.010*"chest" + 0.009*"leav" + 0.008*"small" + 0.008*"lung" + 0.008*"report" + 0.007*"abdomen"

# %%
# train lda model using tf-idf word weights already established
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.004*"pain" + 0.004*"patient" + 0.004*"discharg" + 0.004*"tablet" + 0.003*"respons" + 0.003*"hypertens" + 0.003*"action" + 0.003*"continu" + 0.003*"assess" + 0.003*"leav"
# Topic: 1
# Words: 0.007*"clip" + 0.007*"fractur" + 0.007*"reason" + 0.006*"right" + 0.005*"leav" + 0.005*"carotid" + 0.005*"chest" + 0.004*"view" + 0.004*"line" + 0.004*"contrast"
# Topic: 2
# Words: 0.018*"trace" + 0.012*"wave" + 0.012*"previou" + 0.011*"sinu" + 0.010*"rhythm" + 0.008*"compar" + 0.008*"chang" + 0.006*"signific" + 0.006*"specif" + 0.006*"lead"
# Topic: 3
# Words: 0.004*"tablet" + 0.004*"pain" + 0.003*"note" + 0.003*"order" + 0.003*"resp" + 0.003*"remain" + 0.003*"neuro" + 0.003*"right" + 0.003*"continu" + 0.003*"insulin"
# Topic: 4
# Words: 0.004*"trace" + 0.004*"clip" + 0.004*"patient" + 0.004*"reason" + 0.004*"previou" + 0.003*"tablet" + 0.003*"right" + 0.003*"pain" + 0.003*"chang" + 0.003*"rsbi"
# Topic: 5
# Words: 0.005*"chest" + 0.005*"clip" + 0.004*"reason" + 0.004*"right" + 0.004*"assess" + 0.003*"leav" + 0.003*"vein" + 0.003*"pain" + 0.003*"trace" + 0.003*"pulmonari"
# Topic: 6
# Words: 0.010*"chest" + 0.009*"clip" + 0.008*"reason" + 0.008*"right" + 0.006*"portabl" + 0.006*"effus" + 0.006*"pleural" + 0.005*"pneumothorax" + 0.005*"lung" + 0.005*"leav"
# Topic: 7
# Words: 0.014*"valv" + 0.011*"ventricular" + 0.008*"trace" + 0.008*"mitral" + 0.008*"aortic" + 0.007*"leaflet" + 0.007*"normal" + 0.007*"atrial" + 0.005*"wave" + 0.005*"pace"
# Topic: 8
# Words: 0.009*"contrast" + 0.006*"clip" + 0.005*"hemorrhag" + 0.005*"reason" + 0.005*"mass" + 0.005*"head" + 0.005*"fractur" + 0.004*"brain" + 0.004*"leav" + 0.004*"right"
# Topic: 9
# Words: 0.004*"respiratori" + 0.004*"assess" + 0.004*"continu" + 0.004*"pain" + 0.004*"bipap" + 0.003*"plan" + 0.003*"give" + 0.003*"patient" + 0.003*"respons" + 0.003*"remain"

# %%
## determine which topic a certain document belongs to
#again 765 is a sample index
for index, score in sorted(lda_model[bow_corpus[765]], key=lambda tup: -1*tup[1]):
    print("Score: {}\t \nTopic: {} ".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.9946724772453308
# Topic: 0.012*"patient" + 0.012*"pain" + 0.009*"medic" + 0.009*"assess" + 0.009*"blood" + 0.008*"continu" + 0.008*"hypertens" + 0.007*"histori" + 0.007*"leav" + 0.006*"tablet"
